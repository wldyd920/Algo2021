# %%
# 20

money = 20
count = []
coins = [16, 10, 5, 1]

def minimum_coin() :
  count.sort()
  print(count[0])

for i in coins :
  cnt = 0
  cnt += money // i
  cnt += money % i
  count.append(cnt)

print(count)
minimum_coin()

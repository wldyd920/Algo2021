# %%
n = 4
k = 10
init_pos = [2, 3, 6, 7]

distance = []
fastests=[]

def run():
    for i in init_pos :
        distance.append(k-i)         
        distance.append(i)
    distance.sort(reverse=True)
    print("The Latest time : ", distance[0])
    distance.sort()
    print("The Fastest time : ", distance[0])

run()
# Out:
# The Latest time :  8
# The Fastest time :  2
